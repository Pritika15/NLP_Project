# %%
# !pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 KB 7.8 MB/s eta 0:00:00
# ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
vds=SentimentIntensityAnalyzer()

# %%
# !pip install --upgrade --no-cache-dir gdown
# !gdown 1axYC_zfEOgwmB_GbOMsTeEyFjduWUnwB
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1axYC_zfEOgwmB_GbOMsTeEyFjduWUnwB
# To: /content/6lakhdata.csv
# 100% 62.7M/62.7M [00:00<00:00, 130MB/s]

# %%
import pandas as pd
df=pd.read_csv('6lakhdata.csv')
df.head()
# Out:
#                                                 text
# 0  member medical team dispatched agra based army...
# 1  earthquake relief turkey aerial recovery looki...
# 2  mozaik foundation launched emergency relief fu...
# 3  call contribute earthquake relief come people ...
# 4  compliance royal order sultan haitham bin tari...

# %%
# PolarityScore=[]
label=[]
for docText in df['text']:
  scores=vds.polarity_scores(docText)
  label.append(scores["compound"])

label
# Out:
# [0.7506,
#  0.8176,
#  0.9217,
#  0.8834,
#  0.4767,
#  0.6597,
#  0.7003,
#  0.1027,
#  -0.7906,
#  0.7003,
#  0.802,
#  -0.5574,
#  0.6808,
#  0.4767,
#  0.3818,
#  0.34,
#  0.296,
#  0.25,
#  -0.1779,
#  -0.0516,
#  -0.4215,
#  0.802,
#  0.8519,
#  0.4767,
#  0.7964,
#  0.6597,
#  0.4767,
#  0.4767,
#  -0.5106,
#  0.3182,
#  0.5267,
#  0.9136,
#  -0.1027,
#  0.128,
#  0.5719,
#  0.4939,
#  -0.25,
#  0.7096,
#  -0.2263,
#  0.7003,
#  0.7184,
#  0.9081,
#  0.765,
#  0.8934,
#  0.6597,
#  0.8555,
#  0.4767,
#  0.4767,
#  0.6597,
#  0.2732,
#  0.6369,
#  0.0516,
#  0.7351,
#  0.5719,
#  0.6705,
#  0.8481,
#  0.4767,
#  0.7964,
#  0.6908,
#  -0.7579,
#  0.7351,
#  0.6908,
#  0.4767,
#  0.7003,
#  0.1779,
#  0.2732,
#  -0.0498,
#  0.4767,
#  0.6486,
#  0.8442,
#  -0.9313,
#  0.2263,
#  0.8934,
#  0.7096,
#  0.4767,
#  0.875,
#  0.836,
#  0.6597,
#  -0.2263,
#  0.4767,
#  0.8834,
#  0.1779,
#  0.5574,
#  0.4767,
#  -0.6808,
#  0.7096,
#  0.7003,
#  -0.6369,
#  0.2023,
#  -0.7003,
# ...

# %%
Finallabel=[]
for scoreVal in label:
  if label >0.05 or label ==0.05:
    Finallabel.append(1)
  if label < -0.05 or label ==0.05:  
    Finallabel.append(-1)
  if label > -0.05 and  label < 0.05 : 
    Finallabel.append(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-baf96efe42dc> in <module>
#       1 Finallabel=[]
#       2 for scoreVal in label:
# ----> 3   if label >0.05 or label ==0.05:
#       4     Finallabel.append(1)
#       5   if label < -0.05 or label ==0.05:
#
# TypeError: '>' not supported between instances of 'list' and 'float'
